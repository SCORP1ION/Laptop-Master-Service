# %% [markdown]
# <a href="https://colab.research.google.com/github/SCORP1ION/Laptop-Master-Service/blob/main/PrimerEjercicioIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
datos_cebollitas = pd.read_csv("partidos_cebollitas.csv")

# %%
datos_cebollitas.head()
# Out:
#   fecha_partido     equipo_local equipo_visitante  goles_local  \
# 0    2023-01-01  Atlético Python    Cebollitas FC            2
# 1    2023-01-08       NumPy City  Atlético Python            1
# 2    2023-01-15    Cebollitas FC      Data United            1
# 3    2023-01-22  Atlético Python      Data United            2
# 4    2023-01-29      Data United    Cebollitas FC            5
#
#    goles_visitante  posesion_local (%)  posesion_visitante (%)  \
# 0                0                  54                      46
# 1                5                  60                      40
# 2                0                  55                      45
# 3                3                  57                      43
# 4                3                  52                      48
#
#    tiros_arco_local  tiros_arco_visitante       estadio
# 0                12                     6  Python Arena
# 1                12                     3    Estadio ML
# ...

# %%
datos_cebollitas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   fecha_partido           100 non-null    object
#  1   equipo_local            100 non-null    object
#  2   equipo_visitante        100 non-null    object
#  3   goles_local             100 non-null    int64
#  4   goles_visitante         100 non-null    int64
#  5   posesion_local (%)      100 non-null    int64
#  6   posesion_visitante (%)  100 non-null    int64
#  7   tiros_arco_local        100 non-null    int64
#  8   tiros_arco_visitante    100 non-null    int64
#  9   estadio                 100 non-null    object
# dtypes: int64(6), object(4)
# memory usage: 7.9+ KB

# %%
datos_cebollitas.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   fecha_partido           100 non-null    object
#  1   equipo_local            100 non-null    object
#  2   equipo_visitante        100 non-null    object
#  3   goles_local             100 non-null    int64
#  4   goles_visitante         100 non-null    int64
#  5   posesion_local (%)      100 non-null    int64
#  6   posesion_visitante (%)  100 non-null    int64
#  7   tiros_arco_local        100 non-null    int64
#  8   tiros_arco_visitante    100 non-null    int64
#  9   estadio                 100 non-null    object
# dtypes: int64(6), object(4)
# memory usage: 7.9+ KB

# %%
print("Valores nulos antes de imputacion: ")
# Out:
# Valores nulos antes de imputacion:

# %%
print(datos_cebollitas.isnull().sum())
# Out:
# fecha_partido             0
# equipo_local              0
# equipo_visitante          0
# goles_local               0
# goles_visitante           0
# posesion_local (%)        0
# posesion_visitante (%)    0
# tiros_arco_local          0
# tiros_arco_visitante      0
# estadio                   0
# dtype: int64

# %%
datos_cebollitas['goles_local'] = datos_cebollitas['goles_local'].fillna(datos_cebollitas['goles_local'].mean())

# %%
print("\nValores nulos despues de imputacion:")
# Out:
# Valores nulos despues de imputacion:

# %%
print(datos_cebollitas.isnull().sum())
# Out:
# fecha_partido             0
# equipo_local              0
# equipo_visitante          0
# goles_local               0
# goles_visitante           0
# posesion_local (%)        0
# posesion_visitante (%)    0
# tiros_arco_local          0
# tiros_arco_visitante      0
# estadio                   0
# dtype: int64

# %%
datos_preparados = pd.get_dummies(datos_cebollitas, columns=['equipo_local', 'equipo_visitante'])

# %%
datos_preparados.head()
# Out:
#   fecha_partido  goles_local  goles_visitante  posesion_local (%)  \
# 0    2023-01-01            2                0                  54
# 1    2023-01-08            1                5                  60
# 2    2023-01-15            1                0                  55
# 3    2023-01-22            2                3                  57
# 4    2023-01-29            5                3                  52
#
#    posesion_visitante (%)  tiros_arco_local  tiros_arco_visitante  \
# 0                      46                12                     6
# 1                      40                12                     3
# 2                      45                10                     7
# 3                      43                 3                     3
# 4                      48                 7                    12
#
#         estadio  equipo_local_Atlético Python  equipo_local_Cebollitas FC  \
# 0  Python Arena                          True                       False
# ...

# %%
print("Filas antes de eliminar duplicados: ", len(datos_preparados))
# Out:
# Filas antes de eliminar duplicados:  100

# %%
datos_preparados.drop_duplicates(inplace=True)

# %%
print("Filas despues de eliminar duplicados: ", len(datos_preparados))
# Out:
# Filas despues de eliminar duplicados:  100

# %%
datos_preparados['fecha_partido'] = pd.to_datetime(datos_preparados['fecha_partido'], errors='coerce')

# %%
print("Fechas invalidas (NaT) despues de la conversion:")
# Out:
# Fechas invalidas (NaT) despues de la conversion:

# %%
print(datos_preparados['fecha_partido'].isnull().sum())
# Out:
# 0

# %%
print(datos_preparados.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   fecha_partido                     100 non-null    datetime64[ns]
#  1   goles_local                       100 non-null    int64
#  2   goles_visitante                   100 non-null    int64
#  3   posesion_local (%)                100 non-null    int64
#  4   posesion_visitante (%)            100 non-null    int64
#  5   tiros_arco_local                  100 non-null    int64
#  6   tiros_arco_visitante              100 non-null    int64
#  7   estadio                           100 non-null    object
#  8   equipo_local_Atlético Python      100 non-null    bool
#  9   equipo_local_Cebollitas FC        100 non-null    bool
#  10  equipo_local_Data United          100 non-null    bool
#  11  equipo_local_NumPy City           100 non-null    bool
# ...

# %%
print("Columnas con nulos tras limpieza")
# Out:
# Columnas con nulos tras limpieza

# %%
print(datos_preparados.isnull().sum())
# Out:
# fecha_partido                       0
# goles_local                         0
# goles_visitante                     0
# posesion_local (%)                  0
# posesion_visitante (%)              0
# tiros_arco_local                    0
# tiros_arco_visitante                0
# estadio                             0
# equipo_local_Atlético Python        0
# equipo_local_Cebollitas FC          0
# equipo_local_Data United            0
# equipo_local_NumPy City             0
# equipo_local_Real Pandas            0
# equipo_visitante_Atlético Python    0
# equipo_visitante_Cebollitas FC      0
# equipo_visitante_Data United        0
# equipo_visitante_NumPy City         0
# equipo_visitante_Real Pandas        0
# dtype: int64

# %%
print("Vista final de dataset limpio:")
# Out:
# Vista final de dataset limpio:

# %%
print(f"Dimensiones del dataSet: {datos_preparados.shape}")
# Out:
# Dimensiones del dataSet: (100, 18)

# %%
print(f"Filas: {datos_preparados.shape[0]}, Columnas: {datos_preparados.shape[1]}")
# Out:
# Filas: 100, Columnas: 18

# %%
print("\nPrimeras filas del dataSet:")
# Out:
# Primeras filas del dataSet:

# %%
display(datos_preparados.head())
# Out:
#   fecha_partido  goles_local  goles_visitante  posesion_local (%)  \
# 0    2023-01-01            2                0                  54
# 1    2023-01-08            1                5                  60
# 2    2023-01-15            1                0                  55
# 3    2023-01-22            2                3                  57
# 4    2023-01-29            5                3                  52
#
#    posesion_visitante (%)  tiros_arco_local  tiros_arco_visitante  \
# 0                      46                12                     6
# 1                      40                12                     3
# 2                      45                10                     7
# 3                      43                 3                     3
# 4                      48                 7                    12
#
#         estadio  equipo_local_Atlético Python  equipo_local_Cebollitas FC  \
# 0  Python Arena                          True                       False
# ...

# %%
print("\nUltimas filas del dataSet:")
# Out:
# Ultimas filas del dataSet:

# %%
display(datos_preparados.tail())
# Out:
#    fecha_partido  goles_local  goles_visitante  posesion_local (%)  \
# 95    2024-10-27            4                2                  52
# 96    2024-11-03            4                4                  56
# 97    2024-11-10            5                0                  58
# 98    2024-11-17            2                3                  58
# 99    2024-11-24            2                3                  46
#
#     posesion_visitante (%)  tiros_arco_local  tiros_arco_visitante  \
# 95                      48                11                     5
# 96                      44                 4                     6
# 97                      42                 4                     9
# 98                      42                 9                     9
# 99                      54                 6                     5
#
#              estadio  equipo_local_Atlético Python  \
# 95  Estadio DataCamp                         False
# 96      Campo Pandas                          True
# ...

# %%
print("\nInformacion del dataset  ")
# Out:
# Informacion del dataset

# %%
print(datos_preparados.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   fecha_partido                     100 non-null    datetime64[ns]
#  1   goles_local                       100 non-null    int64
#  2   goles_visitante                   100 non-null    int64
#  3   posesion_local (%)                100 non-null    int64
#  4   posesion_visitante (%)            100 non-null    int64
#  5   tiros_arco_local                  100 non-null    int64
#  6   tiros_arco_visitante              100 non-null    int64
#  7   estadio                           100 non-null    object
#  8   equipo_local_Atlético Python      100 non-null    bool
#  9   equipo_local_Cebollitas FC        100 non-null    bool
#  10  equipo_local_Data United          100 non-null    bool
#  11  equipo_local_NumPy City           100 non-null    bool
# ...

# %%
print("\nEstadiscicas descriptivas:")
# Out:
# Estadiscicas descriptivas:

# %%
display(datos_preparados.describe())
# Out:
#              fecha_partido  goles_local  goles_visitante  posesion_local (%)  \
# count                  100    100.00000       100.000000          100.000000
# mean   2023-12-13 12:00:00      2.63000         2.540000           50.250000
# min    2023-01-01 00:00:00      0.00000         0.000000           40.000000
# 25%    2023-06-23 06:00:00      1.00000         1.000000           45.000000
# 50%    2023-12-13 12:00:00      3.00000         3.000000           51.000000
# 75%    2024-06-03 18:00:00      4.00000         4.000000           55.250000
# max    2024-11-24 00:00:00      5.00000         5.000000           60.000000
# std                    NaN      1.58691         1.788967            6.035878
#
#        posesion_visitante (%)  tiros_arco_local  tiros_arco_visitante
# count              100.000000        100.000000            100.000000
# mean                49.750000          7.580000              7.870000
# ...

# %%
print(f"Shane final del dataSet: {datos_preparados.shape}")
# Out:
# Shane final del dataSet: (100, 18)

# %%
print(f"Filas: {datos_preparados.shape[0]}, columnos: {datos_preparados.shape[1]}")
# Out:
# Filas: 100, columnos: 18

# %%
print(f"Dataset final - Filas: {datos_preparados.shape[0]: ,}, columnas: {datos_preparados.shape[1]} ")
# Out:
# Dataset final - Filas:  100, columnas: 18
